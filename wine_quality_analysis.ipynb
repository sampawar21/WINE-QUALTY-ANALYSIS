# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_red = pd.read_csv("/content/winequality-red (1).csv")
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df_red.shape
# Out:
# (1599, 12)

# %%
df_red.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df_red.loc[100:111]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 100            8.3             0.610         0.30             2.1      0.084
# 101            7.8             0.500         0.30             1.9      0.075
# 102            8.1             0.545         0.18             1.9      0.080
# 103            8.1             0.575         0.22             2.1      0.077
# 104            7.2             0.490         0.24             2.2      0.070
# 105            8.1             0.575         0.22             2.1      0.077
# 106            7.8             0.410         0.68             1.7      0.467
# 107            6.2             0.630         0.31             1.7      0.088
# 108            8.0             0.330         0.53             2.5      0.091
# 109            8.1             0.785         0.52             2.0      0.122
# 110            7.8             0.560         0.19             1.8      0.104
# ...

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df_red.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# there are no null values in this dataset

# %%
df_red['quality'].hist()

# %% [markdown]
# quality variable is mostly concentrated between 5 to 6

# %%
corrl = df_red.corr()
corrl
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.heatmap(corrl,annot=True)

# %% [markdown]
# # **observations
#
#
# *   Alcohol is positively correlated with the quality of red wine.
# *   Alcohol has a weak positive correlation with the pH value.
#
#
# *  Citric acid and density have a weak positive correlation with fixed acidity.
# *   pH has a negative correlation with density, fixed acidity, citric acid, and sulfates

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.boxplot(x='quality',y = 'alcohol',data = df_red)

# %% [markdown]
# The higher the alcohol concentration is, the higher the quality of the wine.

# %%
sns.jointplot(x = 'alcohol',y = 'pH',data = df_red )

# %%
def get_correlation(col_1,col_2):
  corelation = col_1.corr(col_2)
  print(corelation)
col_1 = df_red['alcohol']
col_2 = df_red['pH']
get_correlation(col_1,col_2)
# Out:
# 0.20563250850549836

# %% [markdown]
# white wine

# %%
df_white = pd.read_csv("/content/winequality-white (1).csv")
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_white.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df_red['quality'].mean()
# Out:
# 5.6360225140712945

# %%
df_white['quality'].mean()
# Out:
# 5.87790935075541

# %%
df_red['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df_white['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %%
df_red['quality_cat'] = ['Good' if i>=7 else 'Bad' for i in df_red['quality']]
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_white['quality_cat'] = ['Good' if i>=7 else 'Bad' for i in df_white['quality']]
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
ax = df_red['quality_cat'].value_counts().plot(kind='bar',  figsize=(10, 6), fontsize=13, color='#087E8B')
ax.set_title('Counts of Bad and Good vines', size=20, pad=30)
ax.set_ylabel('Count', fontsize=14)
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df_white['quality_cat'].value_counts().plot(kind='bar',  figsize=(10, 6), fontsize=13, color='#087E8B')
ax.set_title('Counts of Bad and Good vines', size=20, pad=30)
ax.set_ylabel('Count', fontsize=14)
# Out:
# Text(0, 0.5, 'Count')

# %%
df_all = pd.concat([df_red, df_white], axis=0)
df_all
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df1 = df_all.sample(frac = 1)
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 712             8.7              0.69         0.00            3.20      0.084
# 1809            8.8              0.20         0.43           15.00      0.053
# 1023            8.2              0.32         0.42            2.30      0.098
# 506             7.3              0.51         0.26            3.30      0.090
# 3058            6.2              0.25         0.38            7.90      0.045
# ...             ...               ...          ...             ...        ...
# 4144            6.8              0.28         0.29           11.90      0.052
# 581            12.3              0.50         0.49            2.20      0.089
# 4046            7.2              0.17         0.28           17.55      0.050
# 4497            6.3              0.29         0.30            8.10      0.212
# 706             6.2              0.31         0.21            6.30      0.041
#
# ...

# %% [markdown]
# ** Univariate Analysis**
# Quality

# %%
df1['quality'].hist()

# %% [markdown]
# The first thing to notice is that there are few really bad wines, i.e. those whose quality is below 3. In the same way, there are few really good wines, ie, those whose quality is above 8. It's also effort to notice this distribution seems like a normal one.

# %% [markdown]
# alcohol

# %%
sns.boxplot(x = 'alcohol',data = df1)

# %%
df1['alcohol'].hist()

# %% [markdown]
# From the histogram, the cartesian coordinates are adequate to understand this variable distribution, which is concentrated between  9% to 11% values.

# %% [markdown]
# Sulphates

# %%
 df1['sulphates'].describe()
# Out:
# count    6497.000000
# mean        0.531268
# std         0.148806
# min         0.220000
# 25%         0.430000
# 50%         0.510000
# 75%         0.600000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
sns.boxplot('sulphates',data = df1)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df1['sulphates'].hist()

# %% [markdown]
# ccordingly to the dataset documentation, it refers to a wine additive which can contribute to sulfur dioxide gas ( S02 ) levels. This last acts as an antimicrobial and antioxidant. The sulphates levels are measured by the concentration of potassium sulphate in g/dm³.
# maximum concentration is between 0.30 to 0.50
